# %%
from pathlib import Path
from PIL import Image
import torch
import clip

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

def zero_shot_label(img, labels):
    with torch.no_grad():
        i = preprocess(img).unsqueeze(0).to(device)
        t = clip.tokenize([f"a photo of {lbl}" for lbl in labels]).to(device)
        i_feat = model.encode_image(i); t_feat = model.encode_text(t)
        probs = (i_feat @ t_feat.T).softmax(dim=-1).squeeze(0)
        idx = int(probs.argmax().item())
        return labels[idx], probs.tolist()

def evaluate(path_clean, path_poisoned, concept_C, concept_A):
    pc, pp = Path(path_clean), Path(path_poisoned)

    if pc.is_file() and pp.is_file():
        img_c = Image.open(pc).convert("RGB")
        img_p = Image.open(pp).convert("RGB")

        pred_c, probs_c = zero_shot_label(img_c, [concept_C, concept_A])
        pred_p, probs_p = zero_shot_label(img_p, [concept_C, concept_A])

        return {
            "clean_prediction": concept_A if pred_c != concept_C else concept_C,
            "poisoned_prediction": concept_A if pred_p != concept_C else concept_C,
            "C_A_prob_ratio_clean": probs_c,
            "C_A_prob_ratio_poison": probs_p,
            "odds of " + concept_C + " to " + concept_A + " (clean)": str(int(probs_c[0] / probs_c[1])) + " to 1",
            "odds of " + concept_C + " to " + concept_A + " (poisoned)": str(int(probs_p[0] / probs_p[1])) + " to 1",
            "odds increase (poisoned vs clean)": f"{(probs_c[0] / probs_c[1]) / (probs_p[0] / probs_p[1]):.2f} times",
            "odds increase yes/no": (probs_c[0] / probs_c[1]) > (probs_p[0] / probs_p[1])
        }

# %%
from pprint import pprint
import pandas as pd

for i in range(20):
    result = evaluate(f"survey_images/dog{i}_clean.png", f"survey_images/dog{i}_poisoned.png", "a dog", "a cat")
    pprint(f"Image {i} results: {result}\n")
    if i == 0:
        df_results = pd.DataFrame()

    df_results = pd.concat([df_results, pd.DataFrame([result])], ignore_index=True)

    if i == 19:
        df_results.to_csv("dog_results.csv", index=False)
# Out:
# ("Image 0 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.0001442432403564453], "
#  "'C_A_prob_ratio_poison': [0.97607421875, 0.0236968994140625], 'odds of a dog "
#  "to a cat (clean)': '6932 to 1', 'odds of a dog to a cat (poisoned)': '41 to "
#  "1', 'odds increase (poisoned vs clean)': '168.31 times', 'odds increase "
#  "yes/no': True}\n")
# ("Image 1 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.0004513263702392578], "
#  "'C_A_prob_ratio_poison': [1.0, 0.00017404556274414062], 'odds of a dog to a "
#  "cat (clean)': '2214 to 1', 'odds of a dog to a cat (poisoned)': '5745 to 1', "
#  "'odds increase (poisoned vs clean)': '0.39 times', 'odds increase yes/no': "
#  'False}\n')
# ("Image 2 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.00016868114471435547], "
#  "'C_A_prob_ratio_poison': [0.9931640625, 0.00669097900390625], 'odds of a dog "
#  "to a cat (clean)': '5928 to 1', 'odds of a dog to a cat (poisoned)': '148 to "
#  "1', 'odds increase (poisoned vs clean)': '39.94 times', 'odds increase "
#  "yes/no': True}\n")
# ("Image 3 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 7.843971252441406e-05], "
#  "'C_A_prob_ratio_poison': [0.998046875, 0.0017271041870117188], 'odds of a "
#  "dog to a cat (clean)': '12748 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'577 to 1', 'odds increase (poisoned vs clean)': '22.06 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 4 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.0004372596740722656], "
#  "'C_A_prob_ratio_poison': [0.9990234375, 0.0010814666748046875], 'odds of a "
#  "dog to a cat (clean)': '2285 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'923 to 1', 'odds increase (poisoned vs clean)': '2.47 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 5 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.0001214742660522461], "
#  "'C_A_prob_ratio_poison': [0.92626953125, 0.07366943359375], 'odds of a dog "
#  "to a cat (clean)': '8232 to 1', 'odds of a dog to a cat (poisoned)': '12 to "
#  "1', 'odds increase (poisoned vs clean)': '654.74 times', 'odds increase "
#  "yes/no': True}\n")
# ("Image 6 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.00037407875061035156], "
#  "'C_A_prob_ratio_poison': [0.99853515625, 0.0012445449829101562], 'odds of a "
#  "dog to a cat (clean)': '2671 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'802 to 1', 'odds increase (poisoned vs clean)': '3.33 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 7 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.00033545494079589844], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.00070953369140625], 'odds of a "
#  "dog to a cat (clean)': '2979 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'1408 to 1', 'odds increase (poisoned vs clean)': '2.12 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 8 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.00030541419982910156], "
#  "'C_A_prob_ratio_poison': [0.9873046875, 0.01282501220703125], 'odds of a dog "
#  "to a cat (clean)': '3272 to 1', 'odds of a dog to a cat (poisoned)': '76 to "
#  "1', 'odds increase (poisoned vs clean)': '42.51 times', 'odds increase "
#  "yes/no': True}\n")
# ("Image 9 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.00015592575073242188], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.0004239082336425781], 'odds of a "
#  "dog to a cat (clean)': '6413 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'2357 to 1', 'odds increase (poisoned vs clean)': '2.72 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 10 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.000110626220703125], "
#  "'C_A_prob_ratio_poison': [1.0, 0.00015592575073242188], 'odds of a dog to a "
#  "cat (clean)': '9039 to 1', 'odds of a dog to a cat (poisoned)': '6413 to 1', "
#  "'odds increase (poisoned vs clean)': '1.41 times', 'odds increase yes/no': "
#  'True}\n')
# ("Image 11 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.0002378225326538086], "
#  "'C_A_prob_ratio_poison': [0.9990234375, 0.0007672309875488281], 'odds of a "
#  "dog to a cat (clean)': '4204 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'1302 to 1', 'odds increase (poisoned vs clean)': '3.23 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 12 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.0001634359359741211], "
#  "'C_A_prob_ratio_poison': [1.0, 0.00023055076599121094], 'odds of a dog to a "
#  "cat (clean)': '6118 to 1', 'odds of a dog to a cat (poisoned)': '4337 to 1', "
#  "'odds increase (poisoned vs clean)': '1.41 times', 'odds increase yes/no': "
#  'True}\n')
# ("Image 13 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.00021314620971679688], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.0006265640258789062], 'odds of a "
#  "dog to a cat (clean)': '4691 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'1595 to 1', 'odds increase (poisoned vs clean)': '2.94 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 14 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.00037407875061035156], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.00033545494079589844], 'odds of a "
#  "dog to a cat (clean)': '2671 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'2979 to 1', 'odds increase (poisoned vs clean)': '0.90 times', 'odds "
#  "increase yes/no': False}\n")
# ("Image 15 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.00040459632873535156], "
#  "'C_A_prob_ratio_poison': [1.0, 0.00023412704467773438], 'odds of a dog to a "
#  "cat (clean)': '2470 to 1', 'odds of a dog to a cat (poisoned)': '4271 to 1', "
#  "'odds increase (poisoned vs clean)': '0.58 times', 'odds increase yes/no': "
#  'False}\n')
# ("Image 16 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99951171875, 0.0004878044128417969], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.0006771087646484375], 'odds of a "
#  "dog to a cat (clean)': '2049 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'1476 to 1', 'odds increase (poisoned vs clean)': '1.39 times', 'odds "
#  "increase yes/no': True}\n")
# ("Image 17 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.00011962652206420898], "
#  "'C_A_prob_ratio_poison': [1.0, 0.00010889768600463867], 'odds of a dog to a "
#  "cat (clean)': '8359 to 1', 'odds of a dog to a cat (poisoned)': '9182 to 1', "
#  "'odds increase (poisoned vs clean)': '0.91 times', 'odds increase yes/no': "
#  'False}\n')
# ("Image 18 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [0.99853515625, 0.0014104843139648438], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.0004582405090332031], 'odds of a "
#  "dog to a cat (clean)': '707 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'2181 to 1', 'odds increase (poisoned vs clean)': '0.32 times', 'odds "
#  "increase yes/no': False}\n")
# ("Image 19 results: {'clean_prediction': 'a dog', 'poisoned_prediction': 'a "
#  "dog', 'C_A_prob_ratio_clean': [1.0, 0.0001398324966430664], "
#  "'C_A_prob_ratio_poison': [0.99951171875, 0.0003459453582763672], 'odds of a "
#  "dog to a cat (clean)': '7151 to 1', 'odds of a dog to a cat (poisoned)': "
#  "'2889 to 1', 'odds increase (poisoned vs clean)': '2.48 times', 'odds "
#  "increase yes/no': True}\n")
