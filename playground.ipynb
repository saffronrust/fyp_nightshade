# %%
import pickle
import matplotlib.pyplot as plt

# %%
file_path = "poisoned_data/0.p"

with open(file_path, 'rb') as f:
    data = pickle.load(f)

print(data)

image_data = data['img']
plt.imshow(image_data)
# Out:
# {'text': 'Canvas Painting With Funny Dog Cartoons', 'img': <PIL.Image.Image image mode=RGB size=512x512 at 0x1A20F9087D0>}
